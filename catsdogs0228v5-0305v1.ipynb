# %%
# coding:utf-8
 
import keras
from keras.utils import np_utils
from keras.models import Sequential
from keras.layers.convolutional import Conv2D, MaxPooling2D
from keras.layers.core import Dense, Dropout, Activation, Flatten
import numpy as np
from sklearn.model_selection import train_test_split
from PIL import Image
import glob
# Out:
# Using TensorFlow backend.

# %%
folder = ["cats_train_all","dogs_train_all"]
image_size = 50
 
X = []
Y = []
for index, name in enumerate(folder):
    dir = "./cats_and_dogs/" + name
    files = glob.glob(dir + "/*.jpg")
    for i, file in enumerate(files):
        image = Image.open(file)
        image = image.convert("RGB")
        image = image.resize((image_size, image_size))
        data = np.asarray(image)
        X.append(data)
        Y.append(index)
 
X = np.array(X)
Y = np.array(Y)

# %%
X = X.astype('float32')
X = X / 255.0

# %%
# 正解ラベルの形式を変換
Y = np_utils.to_categorical(Y, 4)

# %%
# 学習用データとテストデータ
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.20)

# %%
# CNNを構築
model = Sequential()
 
model.add(Conv2D(32, (3, 3), padding='same',input_shape=X_train.shape[1:]))
model.add(Activation('relu'))
model.add(Conv2D(32, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
 
model.add(Conv2D(64, (3, 3), padding='same'))
model.add(Activation('relu'))
model.add(Conv2D(64, (3, 3)))
model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Dropout(0.25))
 
model.add(Flatten())
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.5))
model.add(Dense(4))
model.add(Activation('softmax'))

# %%
# コンパイル
model.compile(loss='categorical_crossentropy',optimizer='SGD',metrics=['accuracy'])

# %%
#訓練
history = model.fit(X_train, y_train, epochs=1000)
# Out:
# Epoch 1/1000
# 20000/20000 [==============================] - 116s 6ms/step - loss: 0.7190 - accuracy: 0.5151
# Epoch 2/1000
# 20000/20000 [==============================] - 108s 5ms/step - loss: 0.6915 - accuracy: 0.5418
# Epoch 3/1000
# 20000/20000 [==============================] - 110s 5ms/step - loss: 0.6816 - accuracy: 0.5713
# Epoch 4/1000
# 20000/20000 [==============================] - 110s 5ms/step - loss: 0.6707 - accuracy: 0.5854
# Epoch 5/1000
# 20000/20000 [==============================] - 107s 5ms/step - loss: 0.6594 - accuracy: 0.6082
# Epoch 6/1000
# 20000/20000 [==============================] - 107s 5ms/step - loss: 0.6363 - accuracy: 0.6414
# Epoch 7/1000
# 20000/20000 [==============================] - 107s 5ms/step - loss: 0.6160 - accuracy: 0.66641s - loss: 0.6159 - ac
# Epoch 8/1000
# 20000/20000 [==============================] - 107s 5ms/step - loss: 0.6057 - accuracy: 0.6779
# Epoch 9/1000
# ...

# %%
#評価 & 評価結果出力
print(model.evaluate(X_test, y_test))
# Out:
# 5000/5000 [==============================] - 5s 1ms/step
# [0.9845589532852173, 0.8626000285148621]

# %%
#モデルの保存
model.save("model_catsdogs_cnn.h5")

# %%
# モデルの保存
open('inuneko.json',"w").write(model.to_json())

# 学習済みの重みを保存
model.save_weights('inuneko_weight.hdf5')

# %%
#評価 & 評価結果出力
print(model.evaluate(X_test, y_test))
# Out:
# 5000/5000 [==============================] - 6s 1ms/step
# [0.9845589532852173, 0.8626000285148621]

# %%
# モデルの読み込み
model2 = model_from_json(open('and.json', 'r').read())

# 重みの読み込み
model2.load_weights('and_weight.hdf5')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-5d512cb9f0aa> in <module>
#       1 # モデルの読み込み
# ----> 2 model2 = model_from_json(open('and.json', 'r').read())
#       3
#       4 # 重みの読み込み
#       5 model2.load_weights('and_weight.hdf5')
#
# NameError: name 'model_from_json' is not defined

# %%
from keras.models import model_from_json

# %%
# モデルの読み込み
model2 = model_from_json(open('inuneko.json', 'r').read())

# 重みの読み込み
model2.load_weights('inuneko_weight.hdf5')

# %%
#評価 & 評価結果出力
#print(model2.evaluate(X_test, y_test))

# %%
# コンパイル
model2.compile(loss='categorical_crossentropy',optimizer='SGD',metrics=['accuracy'])

# %%
#評価 & 評価結果出力
print(model2.evaluate(X_test, y_test))
# Out:
# 5000/5000 [==============================] - 5s 1ms/step
# [0.16242445902301728, 0.974399983882904]

# %%
from keras.models import load_model
model3 = load_model('model_catsdogs_cnn.h5')

# %%
# コンパイル
model3.compile(loss='categorical_crossentropy',optimizer='SGD',metrics=['accuracy'])

# %%
#評価 & 評価結果出力
print(model3.evaluate(X_test, y_test))
# Out:
# 5000/5000 [==============================] - 5s 922us/step
# [0.16242445902301728, 0.974399983882904]
